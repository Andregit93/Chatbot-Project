# %% [markdown]
# # 1. Import Library yang kita butuhkan
#
# - Pada perintah di bawah kami mengimport semua kebutuhan library yang kami butuhkan,
# - Jika temen temen tidak mau import semua library yang di butuhkan dalam step 1 temen temen cukup import library json saja untuk menghubungkan dataset yang sudah kita buat.
#
# ### Perlu di note sebelumnya di virtual environment kami sudah Install and import library yang di butuhkan seperti **tensorflow, keras, keras-models, pickle, nltk**
#
# Cara install:
#
# - pip install tensorflow
# - pip install keras
# - pip install keras-models
# - pip install pickle
# - pip install nltk

# %%
# import necessary libraries
import warnings
warnings.filterwarnings("ignore")
import nltk
from nltk.stem import WordNetLemmatizer
import json
import pickle

import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD
import random
from keras.models import load_model

# create an object of WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# importing the GL Bot corpus file for pre-processing

words=[]
classes = []
documents = []
ignore_words = ['?', '!']
data_file = open("data.json").read()
intents = json.loads(data_file)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [3], line 10
#       7 import pickle
#       9 import numpy as np
# ---> 10 from tensorflow.keras.models import Sequential
#      11 from tensorflow.keras.layers import Dense, Activation, Dropout
#      12 from tensorflow.keras.optimizers import SGD
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\tensorflow\__init__.py:37
#      34 import sys as _sys
#      35 import typing as _typing
# ---> 37 from tensorflow.python.tools import module_util as _module_util
#      38 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      40 # Make sure code inside the TensorFlow codebase can use tf2.enabled() at import.
#
# ModuleNotFoundError: No module named 'tensorflow.python'

# %% [markdown]
# # 2. Data pre-processing

# %%
# preprocessing the json data
# tokenization
#nltk.download('punkt')
#nltk.download('wordnet')
for intent in intents['intents']:
    for pattern in intent['patterns']:

        #tokenize each word
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        #add documents in the corpus
        documents.append((w, intent['tag']))

        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# %% [markdown]
# ### Tokenisasi
#
# - Pada proses tokenisasi pada dasarnya adalah pemisahan kalimat, paragraf,
# atau seluruh dokumen teks menjadi unit yang lebih kecil, proses itu yang disebut token
#
# - Pada proses ini juga akan save documen tersebut menjadi file label.pkl dan texts.pkl (proses labeling)

# %%
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))

# sort classes
classes = sorted(list(set(classes)))

# documents = combination between patterns and intents
print (len(documents), "documents")

# classes = intents
print (len(classes), "classes", classes)

# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)

# creating a pickle file to store the Python objects which we will use while predicting
pickle.dump(words,open('texts.pkl','wb')) 
pickle.dump(classes,open('labels.pkl','wb'))
# Out:
# 117 documents
# 115 classes ['greeting1', 'greeting10', 'greeting11', 'greeting12', 'greeting13', 'greeting14', 'greeting15', 'greeting16', 'greeting2', 'greeting3', 'greeting4', 'greeting5', 'greeting6', 'greeting7', 'greeting8', 'greeting9', 'greeting_malam', 'noanswer', 'pengalaman1', 'pengalaman2', 'pengalaman3', 'pengalaman4', 'pengalaman5', 'pengalaman6', 'pengalaman7', 'pengalaman8', 'pengalaman9', 'penutup1', 'penutup1a', 'penutup2', 'penutup3', 'penutup4', 'penutup5', 'skill1', 'skill10', 'skill11', 'skill12', 'skill13', 'skill14', 'skill15', 'skill16', 'skill17', 'skill18', 'skill19', 'skill2', 'skill20', 'skill21', 'skill22', 'skill23', 'skill24', 'skill25', 'skill26', 'skill27', 'skill28', 'skill29', 'skill3', 'skill30', 'skill31', 'skill32', 'skill33', 'skill34', 'skill35', 'skill36', 'skill37', 'skill38', 'skill39', 'skill4', 'skill40', 'skill41', 'skill42', 'skill43', 'skill44', 'skill45', 'skill46', 'skill47', 'skill48', 'skill49', 'skill5', 'skill50', 'skill51', 'skill52', 'skill53', 'skill54', 'skill55', 'skill56', 'skill57', 'skill58', 'skill59', 'skill6', 'skill60', 'skill61', 'skill62', 'skill63', 'skill7', 'skill8', 'skill9', 'tools1', 'tools10', 'tools11', 'tools12', 'tools13', 'tools14', 'tools15', 'tools16', 'tools17', 'tools18', 'tools19', 'tools2', 'tools3', 'tools4', 'tools5', 'tools6', 'tools7', 'tools8', 'tools9']
# 153 unique lemmatized words [',', 'adalah', 'algoritma', 'analisis', 'analysis', 'analyst', 'awan', 'bahasa', 'baik', 'baiklah', 'bayes', 'bekerja', 'boost', 'c', 'c++', 'cat', 'classification', 'cloud', 'clustering', 'code', 'coding', 'colab', 'computing', 'customer', 'data', 'database', 'decision', 'deep', 'disesuaikan', 'engineering', 'feature', 'forecasting', 'forest', 'gali', 'ggplot', 'google', 'gradien', 'hai', 'halo', 'hello', 'java', 'javascript', 'jt', 'jupyter', 'juta', 'k', 'k-means', 'karena', 'kasih', 'kelebihan', 'kelemahan', 'keputusan', 'kerja', 'ketahui', 'klasifikasi', 'klustering', 'knn', 'komputasi', 'kuasai', 'language', 'learning', 'library', 'machine', 'magang', 'malam', 'malem', 'manipulasi', 'manipulation', 'masalah', 'matplotlib', 'mean', 'melamar', 'membangun', 'membuat', 'menganalisis', 'mengerjakan', 'menggali', 'menyelesaikan', 'merapihkan', 'merupakan', 'mesin', 'minimum', 'mining', 'model', 'modeling', 'modelling', 'naive', 'nama', 'namaku', 'nearest', 'neighbor', 'network', 'neural', 'notebook', 'numpy', 'object', 'oop', 'oriented', 'pagi', 'panda', 'pembelajaran', 'pemodelan', 'pemrograman', 'perapihan', 'perkenalkan', 'permasalahan', 'pernah', 'php', 'pohon', 'prediksi', 'programmer', 'programming', 'project', 'proyek', 'pycharm', 'python', 'query', 'r', 'random', 'regresi', 'regression', 'rupiah', 'science', 'scientist', 'sebagai', 'selamat', 'selesai', 'service', 'siang', 'sore', 'sql', 'structured', 'studio', 'sublime', 'supervised', 'support', 'svm', 'teller', 'terima', 'text', 'transformasi', 'transformation', 'tree', 'unsupervised', 'upah', 'v', 'vector', 'visual', 'visualisasi', 'visualization', 'wrangling', 'xgboost', 'yaitu']

# %% [markdown]
# # 3. Creating Training Data
#
# - Pada dasarnya, bag of words adalah representasi sederhana dari setiap teks dalam sebuah kalimat sebagai bag of words-nya.

# %%
# create our training data
training = []

# create an empty array for our output
output_empty = [0] * len(classes)

# training set, bag of words for each sentence
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
   
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)
    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    training.append([bag, output_row])

# shuffle features and converting it into numpy arrays
random.shuffle(training)
training = np.array(training)

# create train and test lists
train_x = list(training[:,0])
train_y = list(training[:,1])

print("Training data created")
# Out:
# Training data created

# %% [markdown]
# # 5. Creating Modeling
#
# - Pada proses ini kami akan membuat model jaringan saraf dan menyimpan model tersebut

# %%
# Create NN model to predict the responses
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(learning_rate=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#fitting and saving the model 
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('models.h5', hist) # we will pickle this model to use in the future
print("\n")
print("*"*50)
print("\nModel Created Successfully!")
# Out:
# Epoch 1/200
# 24/24 [==============================] - 1s 2ms/step - loss: 4.7592 - accuracy: 0.0085
# Epoch 2/200
# 24/24 [==============================] - 0s 3ms/step - loss: 4.7529 - accuracy: 0.0085
# Epoch 3/200
# 24/24 [==============================] - 0s 2ms/step - loss: 4.7330 - accuracy: 0.0085
# Epoch 4/200
# 24/24 [==============================] - 0s 3ms/step - loss: 4.7526 - accuracy: 0.0085
# Epoch 5/200
# 24/24 [==============================] - 0s 4ms/step - loss: 4.7192 - accuracy: 0.0171
# Epoch 6/200
# 24/24 [==============================] - 0s 3ms/step - loss: 4.7087 - accuracy: 0.0256
# Epoch 7/200
# 24/24 [==============================] - 0s 2ms/step - loss: 4.6864 - accuracy: 0.0513
# Epoch 8/200
# 24/24 [==============================] - 0s 3ms/step - loss: 4.6815 - accuracy: 0.0256
# Epoch 9/200
# 24/24 [==============================] - 0s 3ms/step - loss: 4.6496 - accuracy: 0.0171
# Epoch 10/200
# 24/24 [==============================] - 0s 3ms/step - loss: 4.6443 - accuracy: 0.0085
# Epoch 11/200
# 24/24 [==============================] - 0s 2ms/step - loss: 4.6147 - accuracy: 0.0427
# Epoch 12/200
# 24/24 [==============================] - 0s 3ms/step - loss: 4.6120 - accuracy: 0.0598
# Epoch 13/200
# 24/24 [==============================] - 0s 3ms/step - loss: 4.5888 - accuracy: 0.0513
# Epoch 14/200
# 24/24 [==============================] - 0s 3ms/step - loss: 4.5449 - accuracy: 0.0513
# Epoch 15/200
# 24/24 [==============================] - 0s 2ms/step - loss: 4.5190 - accuracy: 0.0855
# Epoch 16/200
# 24/24 [==============================] - 0s 3ms/step - loss: 4.4926 - accuracy: 0.0342
# Epoch 17/200
# 24/24 [==============================] - 0s 3ms/step - loss: 4.4193 - accuracy: 0.0769
# Epoch 18/200
# 24/24 [==============================] - 0s 3ms/step - loss: 4.3756 - accuracy: 0.0598
# Epoch 19/200
# 24/24 [==============================] - 0s 3ms/step - loss: 4.3532 - accuracy: 0.0342
# Epoch 20/200
# 24/24 [==============================] - 0s 3ms/step - loss: 4.2988 - accuracy: 0.0598
# Epoch 21/200
# 24/24 [==============================] - 0s 3ms/step - loss: 4.2585 - accuracy: 0.1368
# Epoch 22/200
# 24/24 [==============================] - 0s 3ms/step - loss: 4.1918 - accuracy: 0.0940
# Epoch 23/200
# 24/24 [==============================] - 0s 3ms/step - loss: 4.1456 - accuracy: 0.0684
# Epoch 24/200
# 24/24 [==============================] - 0s 3ms/step - loss: 4.1874 - accuracy: 0.1111
# Epoch 25/200
# 24/24 [==============================] - 0s 3ms/step - loss: 4.0150 - accuracy: 0.1197
# Epoch 26/200
# 24/24 [==============================] - 0s 3ms/step - loss: 3.9522 - accuracy: 0.1197
# Epoch 27/200
# 24/24 [==============================] - 0s 3ms/step - loss: 3.8617 - accuracy: 0.1538
# Epoch 28/200
# 24/24 [==============================] - 0s 2ms/step - loss: 3.7714 - accuracy: 0.2222
# Epoch 29/200
# 24/24 [==============================] - 0s 3ms/step - loss: 3.7975 - accuracy: 0.1282
# Epoch 30/200
# 24/24 [==============================] - 0s 2ms/step - loss: 3.7116 - accuracy: 0.1538
# Epoch 31/200
# 24/24 [==============================] - 0s 3ms/step - loss: 3.5740 - accuracy: 0.1795
# Epoch 32/200
# 24/24 [==============================] - 0s 2ms/step - loss: 3.5522 - accuracy: 0.1453
# Epoch 33/200
# 24/24 [==============================] - 0s 3ms/step - loss: 3.3231 - accuracy: 0.2393
# Epoch 34/200
# 24/24 [==============================] - 0s 3ms/step - loss: 3.3307 - accuracy: 0.2308
# Epoch 35/200
# 24/24 [==============================] - 0s 2ms/step - loss: 3.2735 - accuracy: 0.2735
# Epoch 36/200
# 24/24 [==============================] - 0s 2ms/step - loss: 3.1541 - accuracy: 0.2564
# Epoch 37/200
# 24/24 [==============================] - 0s 3ms/step - loss: 3.3030 - accuracy: 0.1880
# Epoch 38/200
# 24/24 [==============================] - 0s 2ms/step - loss: 3.0402 - accuracy: 0.3077
# Epoch 39/200
# 24/24 [==============================] - 0s 3ms/step - loss: 2.9080 - accuracy: 0.3419
# Epoch 40/200
# 24/24 [==============================] - 0s 3ms/step - loss: 2.9489 - accuracy: 0.3162
# Epoch 41/200
# 24/24 [==============================] - 0s 3ms/step - loss: 2.9055 - accuracy: 0.2393
# Epoch 42/200
# 24/24 [==============================] - 0s 3ms/step - loss: 2.6287 - accuracy: 0.3419
# Epoch 43/200
# 24/24 [==============================] - 0s 2ms/step - loss: 2.7667 - accuracy: 0.2991
# Epoch 44/200
# 24/24 [==============================] - 0s 3ms/step - loss: 2.5768 - accuracy: 0.3504
# Epoch 45/200
# 24/24 [==============================] - 0s 3ms/step - loss: 2.3933 - accuracy: 0.4017
# Epoch 46/200
# 24/24 [==============================] - 0s 3ms/step - loss: 2.4393 - accuracy: 0.4274
# Epoch 47/200
# 24/24 [==============================] - 0s 2ms/step - loss: 2.4260 - accuracy: 0.3932
# Epoch 48/200
# 24/24 [==============================] - 0s 3ms/step - loss: 2.4929 - accuracy: 0.3590
# Epoch 49/200
# 24/24 [==============================] - 0s 3ms/step - loss: 2.5238 - accuracy: 0.3504
# Epoch 50/200
# 24/24 [==============================] - 0s 3ms/step - loss: 2.4395 - accuracy: 0.3333
# Epoch 51/200
# 24/24 [==============================] - 0s 3ms/step - loss: 2.2404 - accuracy: 0.4103
# Epoch 52/200
# 24/24 [==============================] - 0s 3ms/step - loss: 2.2750 - accuracy: 0.4188
# Epoch 53/200
# 24/24 [==============================] - 0s 3ms/step - loss: 2.1906 - accuracy: 0.3846
# Epoch 54/200
# 24/24 [==============================] - 0s 3ms/step - loss: 2.0887 - accuracy: 0.4615
# Epoch 55/200
# 24/24 [==============================] - 0s 3ms/step - loss: 2.0663 - accuracy: 0.4444
# Epoch 56/200
# 24/24 [==============================] - 0s 2ms/step - loss: 1.9683 - accuracy: 0.4530
# Epoch 57/200
# 24/24 [==============================] - 0s 3ms/step - loss: 1.9011 - accuracy: 0.4957
# Epoch 58/200
# 24/24 [==============================] - 0s 2ms/step - loss: 1.8683 - accuracy: 0.5214
# Epoch 59/200
# 24/24 [==============================] - 0s 3ms/step - loss: 1.7204 - accuracy: 0.5556
# Epoch 60/200
# 24/24 [==============================] - 0s 2ms/step - loss: 1.9501 - accuracy: 0.4701
# Epoch 61/200
# 24/24 [==============================] - 0s 2ms/step - loss: 1.7236 - accuracy: 0.5299
# Epoch 62/200
# 24/24 [==============================] - 0s 3ms/step - loss: 2.0397 - accuracy: 0.4872
# Epoch 63/200
# 24/24 [==============================] - 0s 2ms/step - loss: 1.6998 - accuracy: 0.5214
# Epoch 64/200
# 24/24 [==============================] - 0s 3ms/step - loss: 1.7297 - accuracy: 0.5385
# Epoch 65/200
# 24/24 [==============================] - 0s 3ms/step - loss: 1.6826 - accuracy: 0.5726
# Epoch 66/200
# 24/24 [==============================] - 0s 3ms/step - loss: 1.8560 - accuracy: 0.4786
# Epoch 67/200
# 24/24 [==============================] - 0s 3ms/step - loss: 1.6815 - accuracy: 0.5470
# Epoch 68/200
# 24/24 [==============================] - 0s 2ms/step - loss: 1.6176 - accuracy: 0.5897
# Epoch 69/200
# 24/24 [==============================] - 0s 3ms/step - loss: 1.5310 - accuracy: 0.5726
# Epoch 70/200
# 24/24 [==============================] - 0s 3ms/step - loss: 1.5997 - accuracy: 0.5812
# Epoch 71/200
# 24/24 [==============================] - 0s 2ms/step - loss: 1.5195 - accuracy: 0.6068
# Epoch 72/200
# 24/24 [==============================] - 0s 3ms/step - loss: 1.4175 - accuracy: 0.6154
# Epoch 73/200
# 24/24 [==============================] - 0s 2ms/step - loss: 1.4744 - accuracy: 0.5983
# Epoch 74/200
# 24/24 [==============================] - 0s 2ms/step - loss: 1.4430 - accuracy: 0.6068
# Epoch 75/200
# 24/24 [==============================] - 0s 3ms/step - loss: 1.4666 - accuracy: 0.6239
# Epoch 76/200
# 24/24 [==============================] - 0s 2ms/step - loss: 1.2998 - accuracy: 0.6410
# Epoch 77/200
# 24/24 [==============================] - 0s 3ms/step - loss: 1.2034 - accuracy: 0.6923
# Epoch 78/200
# 24/24 [==============================] - 0s 3ms/step - loss: 1.2831 - accuracy: 0.6667
# Epoch 79/200
# 24/24 [==============================] - 0s 2ms/step - loss: 1.3451 - accuracy: 0.6410
# Epoch 80/200
# 24/24 [==============================] - 0s 3ms/step - loss: 1.2300 - accuracy: 0.6154
# Epoch 81/200
# 24/24 [==============================] - 0s 2ms/step - loss: 1.3091 - accuracy: 0.6581
# Epoch 82/200
# 24/24 [==============================] - 0s 2ms/step - loss: 1.3126 - accuracy: 0.6496
# Epoch 83/200
# 24/24 [==============================] - 0s 3ms/step - loss: 1.4297 - accuracy: 0.5983
# Epoch 84/200
# 24/24 [==============================] - 0s 3ms/step - loss: 1.1570 - accuracy: 0.6667
# Epoch 85/200
# 24/24 [==============================] - 0s 3ms/step - loss: 1.0684 - accuracy: 0.7179
# Epoch 86/200
# 24/24 [==============================] - 0s 3ms/step - loss: 1.2036 - accuracy: 0.7436
# Epoch 87/200
# 24/24 [==============================] - 0s 3ms/step - loss: 1.1880 - accuracy: 0.6410
# Epoch 88/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.9895 - accuracy: 0.7521
# Epoch 89/200
# 24/24 [==============================] - 0s 3ms/step - loss: 1.0323 - accuracy: 0.7265
# Epoch 90/200
# 24/24 [==============================] - 0s 3ms/step - loss: 1.0649 - accuracy: 0.7009
# Epoch 91/200
# 24/24 [==============================] - 0s 3ms/step - loss: 1.2653 - accuracy: 0.6667
# Epoch 92/200
# 24/24 [==============================] - 0s 3ms/step - loss: 1.2309 - accuracy: 0.6667
# Epoch 93/200
# 24/24 [==============================] - 0s 2ms/step - loss: 1.1543 - accuracy: 0.7179
# Epoch 94/200
# 24/24 [==============================] - 0s 2ms/step - loss: 1.2689 - accuracy: 0.6239
# Epoch 95/200
# 24/24 [==============================] - 0s 3ms/step - loss: 1.1403 - accuracy: 0.6923
# Epoch 96/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.8443 - accuracy: 0.7949
# Epoch 97/200
# 24/24 [==============================] - 0s 2ms/step - loss: 1.0324 - accuracy: 0.7009
# Epoch 98/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.8904 - accuracy: 0.7863
# Epoch 99/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.9994 - accuracy: 0.6496
# Epoch 100/200
# 24/24 [==============================] - 0s 2ms/step - loss: 1.0933 - accuracy: 0.6667
# Epoch 101/200
# 24/24 [==============================] - 0s 3ms/step - loss: 1.0622 - accuracy: 0.6752
# Epoch 102/200
# 24/24 [==============================] - 0s 2ms/step - loss: 1.0827 - accuracy: 0.7179
# Epoch 103/200
# 24/24 [==============================] - 0s 3ms/step - loss: 1.0714 - accuracy: 0.7009
# Epoch 104/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7999 - accuracy: 0.7265
# Epoch 105/200
# 24/24 [==============================] - 0s 3ms/step - loss: 1.1326 - accuracy: 0.7179
# Epoch 106/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.9930 - accuracy: 0.6923
# Epoch 107/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.9201 - accuracy: 0.7350
# Epoch 108/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.7883 - accuracy: 0.7949
# Epoch 109/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.9922 - accuracy: 0.7436
# Epoch 110/200
# 24/24 [==============================] - 0s 3ms/step - loss: 1.0454 - accuracy: 0.6496
# Epoch 111/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.9539 - accuracy: 0.7179
# Epoch 112/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.9699 - accuracy: 0.7350
# Epoch 113/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.8453 - accuracy: 0.7521
# Epoch 114/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.8254 - accuracy: 0.7436
# Epoch 115/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.8275 - accuracy: 0.7436
# Epoch 116/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.8999 - accuracy: 0.6838
# Epoch 117/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.7614 - accuracy: 0.7607
# Epoch 118/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.8030 - accuracy: 0.7949
# Epoch 119/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.9173 - accuracy: 0.7436
# Epoch 120/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.8141 - accuracy: 0.7778
# Epoch 121/200
# 24/24 [==============================] - 0s 3ms/step - loss: 1.0130 - accuracy: 0.7265
# Epoch 122/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.7552 - accuracy: 0.8034
# Epoch 123/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.8270 - accuracy: 0.7607
# Epoch 124/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.7676 - accuracy: 0.7778
# Epoch 125/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.9156 - accuracy: 0.7436
# Epoch 126/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.7579 - accuracy: 0.7692
# Epoch 127/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.7893 - accuracy: 0.7521
# Epoch 128/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.8714 - accuracy: 0.7436
# Epoch 129/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.7563 - accuracy: 0.7778
# Epoch 130/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.9274 - accuracy: 0.7179
# Epoch 131/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.7731 - accuracy: 0.8291
# Epoch 132/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.9267 - accuracy: 0.7350
# Epoch 133/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.7829 - accuracy: 0.7949
# Epoch 134/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.9263 - accuracy: 0.7350
# Epoch 135/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.9103 - accuracy: 0.6923
# Epoch 136/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.8063 - accuracy: 0.7436
# Epoch 137/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.8003 - accuracy: 0.7179
# Epoch 138/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.8249 - accuracy: 0.7778
# Epoch 139/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6846 - accuracy: 0.8034
# Epoch 140/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6274 - accuracy: 0.8205
# Epoch 141/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.7555 - accuracy: 0.7607
# Epoch 142/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6734 - accuracy: 0.8376
# Epoch 143/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.8112 - accuracy: 0.7778
# Epoch 144/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6119 - accuracy: 0.8034
# Epoch 145/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.7254 - accuracy: 0.8291
# Epoch 146/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6914 - accuracy: 0.7949
# Epoch 147/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.7341 - accuracy: 0.8034
# Epoch 148/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7777 - accuracy: 0.7863
# Epoch 149/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.4911 - accuracy: 0.8718
# Epoch 150/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6689 - accuracy: 0.7778
# Epoch 151/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.9101 - accuracy: 0.7692
# Epoch 152/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.7788 - accuracy: 0.7778
# Epoch 153/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.7156 - accuracy: 0.7949
# Epoch 154/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.7589 - accuracy: 0.8205
# Epoch 155/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.7713 - accuracy: 0.7778
# Epoch 156/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6177 - accuracy: 0.8034
# Epoch 157/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6591 - accuracy: 0.8034
# Epoch 158/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.9307 - accuracy: 0.7436
# Epoch 159/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6714 - accuracy: 0.8205
# Epoch 160/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6967 - accuracy: 0.7949
# Epoch 161/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6196 - accuracy: 0.8205
# Epoch 162/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.9265 - accuracy: 0.7350
# Epoch 163/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.7471 - accuracy: 0.8034
# Epoch 164/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.7371 - accuracy: 0.7949
# Epoch 165/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6041 - accuracy: 0.8120
# Epoch 166/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5903 - accuracy: 0.8291
# Epoch 167/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6760 - accuracy: 0.7949
# Epoch 168/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6675 - accuracy: 0.7607
# Epoch 169/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5353 - accuracy: 0.8547
# Epoch 170/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5268 - accuracy: 0.8547
# Epoch 171/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7598 - accuracy: 0.7607
# Epoch 172/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.8431 - accuracy: 0.7350
# Epoch 173/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7440 - accuracy: 0.7521
# Epoch 174/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5603 - accuracy: 0.7949
# Epoch 175/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6008 - accuracy: 0.8376
# Epoch 176/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.4732 - accuracy: 0.8291
# Epoch 177/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6447 - accuracy: 0.8291
# Epoch 178/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7405 - accuracy: 0.7350
# Epoch 179/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6210 - accuracy: 0.7863
# Epoch 180/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.4727 - accuracy: 0.8462
# Epoch 181/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.7431 - accuracy: 0.7692
# Epoch 182/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6022 - accuracy: 0.7949
# Epoch 183/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.7147 - accuracy: 0.7521
# Epoch 184/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6674 - accuracy: 0.8120
# Epoch 185/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7364 - accuracy: 0.7863
# Epoch 186/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5689 - accuracy: 0.8120
# Epoch 187/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.4808 - accuracy: 0.8291
# Epoch 188/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6407 - accuracy: 0.7778
# Epoch 189/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5857 - accuracy: 0.8120
# Epoch 190/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5806 - accuracy: 0.8547
# Epoch 191/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6179 - accuracy: 0.7949
# Epoch 192/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6422 - accuracy: 0.8376
# Epoch 193/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7329 - accuracy: 0.7607
# Epoch 194/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6672 - accuracy: 0.8034
# Epoch 195/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6857 - accuracy: 0.8205
# Epoch 196/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6264 - accuracy: 0.8205
# Epoch 197/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5529 - accuracy: 0.7949
# Epoch 198/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5720 - accuracy: 0.8376
# Epoch 199/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4942 - accuracy: 0.8547
# Epoch 200/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.4404 - accuracy: 0.8632
#
#
# **************************************************
#
# Model Created Successfully!
